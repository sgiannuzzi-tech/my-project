# %% [markdown]
# # analisi dataset nasa c-mapss

# %%
import os 
os.chdir('/workspaces/my-project/')

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

#Definiamo i nomi delle 26 colonne indicati nella documentazione pdf
nomi_colonne = ['id_motore','ciclo','altitudine','velocita_mach','manetta_tra','T2', 'T24', 'T30', 'T50', 'P2',
                 'P15', 'P30', 'Nf', 'Nc', 'epr','Ps30', 'phi', 'NRf', 'NRc','BPR','farB', 'htBleed', 'Nf_dmd', 
                 'PCNf_dmd','W31','W32'
]

# [span_4](start_span)Carichiamo il dataset usando il percorso calcolato nella cella precedente[span_4](end_span)
df_train = pd.read_csv('data/train_FD001.txt', sep=r'\s+', names=nomi_colonne)

# Mostriamo un riepilogo e la tabella interattiva ai tutor
print(f"Matrice C-MAPSS caricata correttamente! Formato: {df_train.shape} (Righe x Colonne)")
display(df_train.head())
# Out:
# Matrice C-MAPSS caricata correttamente! Formato: (20631, 26) (Righe x Colonne)
#    id_motore  ciclo  altitudine  velocita_mach  manetta_tra      T2     T24  \
# 0          1      1     -0.0007        -0.0004        100.0  518.67  641.82
# 1          1      2      0.0019        -0.0003        100.0  518.67  642.15
# 2          1      3     -0.0043         0.0003        100.0  518.67  642.35
# 3          1      4      0.0007         0.0000        100.0  518.67  642.35
# 4          1      5     -0.0019        -0.0002        100.0  518.67  642.37
#
#        T30      T50     P2    P15     P30       Nf       Nc  epr   Ps30  \
# 0  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19  1.3  47.47
# 1  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07  1.3  47.49
# 2  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94  1.3  47.27
# 3  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48  1.3  47.13
# ...

# %%
df_train.set_index(['id_motore', 'ciclo'], verify_integrity=True)
# Out:
# /tmp/ipykernel_14163/3704896932.py:1: Pandas4Warning: The 'verify_integrity' keyword in DataFrame.set_index is deprecated and will be removed in a future version. Directly check the result.index.is_unique instead.
#   df_train.set_index(['id_motore', 'ciclo'], verify_integrity=True)
#                  altitudine  velocita_mach  manetta_tra      T2     T24  \
# id_motore ciclo
# 1         1         -0.0007        -0.0004        100.0  518.67  641.82
#           2          0.0019        -0.0003        100.0  518.67  642.15
#           3         -0.0043         0.0003        100.0  518.67  642.35
#           4          0.0007         0.0000        100.0  518.67  642.35
#           5         -0.0019        -0.0002        100.0  518.67  642.37
# ...                     ...            ...          ...     ...     ...
# 100       196       -0.0004        -0.0003        100.0  518.67  643.49
#           197       -0.0016        -0.0005        100.0  518.67  643.54
# ...

# %%
df_train.describe()
# Out:
#           id_motore         ciclo    altitudine  velocita_mach  manetta_tra  \
# count  20631.000000  20631.000000  20631.000000   20631.000000      20631.0
# mean      51.506568    108.807862     -0.000009       0.000002        100.0
# std       29.227633     68.880990      0.002187       0.000293          0.0
# min        1.000000      1.000000     -0.008700      -0.000600        100.0
# 25%       26.000000     52.000000     -0.001500      -0.000200        100.0
# 50%       52.000000    104.000000      0.000000       0.000000        100.0
# 75%       77.000000    156.000000      0.001500       0.000300        100.0
# max      100.000000    362.000000      0.008700       0.000600        100.0
#
#              T2           T24           T30           T50            P2  \
# count  20631.00  20631.000000  20631.000000  20631.000000  2.063100e+04
# mean     518.67    642.680934   1590.523119   1408.933782  1.462000e+01
# ...
